# %%
from datetime import date, datetime
import pandas as pd
import calendar
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()
import jugaad_data.nse as nse

# %%
stock = nse.stock_df(symbol="TATAPOWER", from_date=date(2005,8,1), to_date=datetime.now().date())
stock['M'] = stock['DATE'].dt.month
stock['Y'] = stock['DATE'].dt.year
stock
# Out:
#            DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0    2022-01-06     EQ  221.45  229.80  219.50       223.50  229.05  228.45
# 1    2022-01-05     EQ  226.40  226.55  223.00       226.30  223.30  223.50
# 2    2022-01-04     EQ  224.30  228.25  221.00       223.40  226.60  226.30
# 3    2022-01-03     EQ  221.20  223.90  216.00       220.95  223.75  223.40
# 4    2021-12-31     EQ  218.90  222.00  218.35       218.35  220.95  220.95
# ...         ...    ...     ...     ...     ...          ...     ...     ...
# 4070 2005-08-05     EQ  415.00  431.95  413.15       408.35  431.00  428.95
# 4071 2005-08-04     EQ  408.00  411.90  399.95       406.90  407.20  408.35
# 4072 2005-08-03     EQ  412.00  416.75  405.00       410.10  405.00  406.90
# 4073 2005-08-02     EQ  407.90  415.00  405.55       403.40  410.00  410.10
# 4074 2005-08-01     EQ  394.00  404.80  392.50       393.20  402.10  403.40
#
#         VWAP   52W H   52W L    VOLUME         VALUE  NO OF TRADES     SYMBOL  \
# 0     225.34  267.85   74.45  27537005  6.205270e+09        161473  TATAPOWER
# 1     224.11  267.85   74.45  17271276  3.870609e+09        132531  TATAPOWER
# 2     224.91  267.85   74.45  32469988  7.302683e+09        187641  TATAPOWER
# 3     222.00  267.85   74.45  19062825  4.231970e+09        143273  TATAPOWER
# 4     220.72  267.85   74.45  12737974  2.811578e+09         78850  TATAPOWER
# ...      ...     ...     ...       ...           ...           ...        ...
# 4070  424.25  431.95  212.50   1474202  6.254324e+08             0  TATAPOWER
# 4071  407.38  430.00  212.50    252380  1.028158e+08             0  TATAPOWER
# 4072  411.07  430.00  212.50    318674  1.309979e+08             0  TATAPOWER
# 4073  410.68  430.00  212.50    649289  2.666531e+08             0  TATAPOWER
# 4074  400.72  430.00  212.50    180214  7.221603e+07             0  TATAPOWER
#
#        M     Y
# 0      1  2022
# 1      1  2022
# 2      1  2022
# 3      1  2022
# 4     12  2021
# ...   ..   ...
# 4070   8  2005
# 4071   8  2005
# 4072   8  2005
# 4073   8  2005
# 4074   8  2005
#
# [4075 rows x 17 columns]

# %%
stock.sort_values('DATE', inplace=True)
stock.reset_index(drop=True, inplace=True)

# %%
stock.set_index('DATE', inplace=True)

# %%
stock_monthly = stock.resample("M").last()

# %%
stock_monthly['Returns'] = (stock_monthly['CLOSE'] - stock_monthly['CLOSE'].shift(1))*100/stock_monthly['CLOSE'].shift(1)

# %%
heatmap_ret = pd.pivot_table(stock_monthly, index='Y', columns='M', values=['Returns'])

# %%
heatmap_ret.columns = [calendar.month_name[i] for i in range(1,13) ]

# %%
plott = plt.figure(figsize=(16, 10))
ax = sns.heatmap(heatmap_ret, cmap='CMRmap', annot=True)
ax.tick_params(top=True, labeltop=True)
