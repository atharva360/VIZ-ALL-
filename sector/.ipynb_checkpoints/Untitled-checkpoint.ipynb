# %%
from nsetools import Nse
import pandas as pd
import numpy as np
import plotly.express as px
import pandas_datareader as data
nse= Nse()

# %%
ipo = pd.read_csv('IPO.CSV')
# i = ipo.set_index('satus').T.to_dict('index')
ipo.set_index('satus',inplace=True)
ipo = ipo.T
ipo
# Out:
# satus                                                            o  \
# company name                             AGS Transact Technologies
# issue size (cr)                                                680
# issue price                                                166-175
# lot size                                                        85
# open date                                                   19-Jan
# close date                                                  21-Jan
# about            AGS Transact is an integrated omni-channel pay...
#
# satus                                                           uc  \
# company name                                                   LIC
# issue size (cr)                                                 Na
# issue price                                                     Na
# lot size                                                        Na
# open date                                                       Na
# close date                                                      Na
# about            Life Insurance Corporation is the only governm...
#
# satus                                                           uc  \
# company name                                          Bajaj Energy
# issue size (cr)                                                 Na
# issue price                                                     Na
# lot size                                                        Na
# open date                                                       Na
# close date                                                      Na
# about            Bajaj Energy Ltd. (BEL) and Lalitpur Power Gen...
#
# satus                                                           uc  \
# company name                                                Go Air
# issue size (cr)                                                 Na
# issue price                                                     Na
# lot size                                                        Na
# open date                                                       Na
# close date                                                      Na
# about            GoFirst, earlier known as Go Air, is an ultra-...
#
# satus                                                           uc  \
# company name                                              Mobikwik
# issue size (cr)                                                 Na
# issue price                                                     Na
# lot size                                                        Na
# open date                                                       Na
# close date                                                      Na
# about            One MobiKwik Systems Limited commenced operati...
#
# satus                                                           uc  \
# company name                                                   OYO
# issue size (cr)                                                 Na
# issue price                                                     Na
# lot size                                                        Na
# open date                                                       Na
# close date                                                      Na
# about            OYO is a leading, new-age technology platform ...
#
# satus                                                           uc  \
# company name                                              Snapdeal
# issue size (cr)                                                 Na
# issue price                                                     Na
# lot size                                                        Na
# open date                                                       Na
# close date                                                      Na
# about            Jasper Infotech is the holding company that ow...
#
# satus                                                           rc
# company name                                        DJ Mediaprint
# issue size (cr)                                                 15
# issue price                                                    125
# lot size                                                      1000
# open date                                                   18-Jan
# close date                                                  20-Jan
# about            DJ Mediaprint & Logistics Ltd. is a leading pr...

# %%
i = ipo.to_dict('records')
i
# Out:
# C:\Users\Atharva\AppData\Local\Temp/ipykernel_3120/1271422332.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   i = ipo.to_dict('records')
# [{'o': 'AGS Transact Technologies', 'uc': 'Snapdeal', 'rc': 'DJ Mediaprint '},
#  {'o': '680', 'uc': 'Na', 'rc': '15'},
#  {'o': '166-175', 'uc': 'Na', 'rc': '125'},
#  {'o': '85', 'uc': 'Na', 'rc': '1000'},
#  {'o': '19-Jan', 'uc': 'Na', 'rc': '18-Jan'},
#  {'o': '21-Jan', 'uc': 'Na', 'rc': '20-Jan'},
#  {'o': 'AGS Transact is an integrated omni-channel payment solutions provider in India. The company provides customised products and services comprising ATM and CRM outsourcing, cash management and digital payment solutions including merchant solutions, transaction processing services and mobile wallets. As per Ken ATM Report, AGS Transact was the second largest company in India in terms of revenue from ATM managed services under the outsourcing model, and revenue from cash management and number of ATMs replenished, as of March 31, 2021. ',
#   'uc': 'Jasper Infotech is the holding company that owns Snapdeal. The company was founded in 2007 as a coupon booklet business and transformed into an online deals platform in 2010. Subsequently, in 2012, it changed into an online marketplace. The platform hosts a wide selection of merchandise across lifestyle categories. It serves users across the nation but intends to attract value buyers who belong to the mid-income segment and are predominantly located in Tier 2+ cities of India.',
#   'rc': 'DJ Mediaprint & Logistics Ltd. is a leading provider of Integrated Printing, Logistics and Courier solutions in India and overseas with extraordinarily networked transport operations, pre-eminent quality standards and leading processes & operations. It also provides Bulk Mailing, Speed Post, Records.'}]

# %%
df = pd.read_csv('sector.csv')
# w = df.set_index('symbol').T.to_dict('index')
# w
df
# Out:
#          symbol industry
# 0    bharatforg     auto
# 1      exideind     auto
# 2    balkrisind     auto
# 3      boschltd     auto
# 4           mrf     auto
# ..          ...      ...
# 107     ipcalab   pharma
# 108  lauruslabs   pharma
# 109  natcopharm   pharma
# 110      pfizer   pharma
# 111        star   pharma
#
# [112 rows x 2 columns]

# %%
n = []
for ind in df.index:
    val = nse.get_quote(df['symbol'][ind])['pChange']
    n.append(val)

# %%
df['% Change'] = n
df["% Change"] = df["% Change"].astype(object).astype(float)
df['industry'].unique()
# Out:
# array(['auto', 'bank', 'fmcg', 'it', 'media', 'metal', 'pharma',
#        'oilandgas'], dtype=object)

# %%
# df.drop(df[df['industry']!='oilandgas'].index, inplace = True)
media = df.query("industry=='media'")
media
# Out:
#         symbol industry  % Change
# 50     tvtoday    media      2.87
# 51  tv18brdcst    media      1.58
# 52      dbcorp    media      1.33
# 53         pvr    media      0.07
# 54      jagran    media     -0.39
# 55       suntv    media     -0.57
# 56        zeel    media     -1.06
# 57   network18    media     -0.55
# 58  inoxleisur    media     -1.90
# 59      dishtv    media     -3.06

# %%
fig = px.bar(df, y =(df['industry']='fmcg'), x=df['% Change'], 
             title='Sectors',text = df['% Change'],
             orientation='h',
#              marker_color=stock['Color']
             )
fig.update_traces(textfont_size=12, textangle=0, textposition="inside", cliponaxis=False)
fig.show()
# Out:
#   File "C:\Users\Atharva\AppData\Local\Temp/ipykernel_15324/4203270647.py", line 1
#     fig = px.bar(df, y =(df['industry']='fmcg'), x=df['% Change'],
#                                        ^
# SyntaxError: invalid syntax

# %%
w = {'bharatforg': 'auto',
  'exideind': 'auto',
  'balkrisind': 'auto',
  'boschltd': 'auto',
  'mrf': 'auto',
  'maruti': 'auto',
  'ashokley': 'auto',
  'tvsmotor': 'auto',
  'tatamotors': 'auto',
  'bajaj-auto': 'auto',
  'eichermot': 'auto',
  'amarajabat': 'auto',
  'heromotoco': 'auto',
  'federalbnk': 'bank',
  'rblbank': 'bank',
  'bandhanbnk': 'bank',
  'aubank': 'bank',
  'pnb': 'bank',
  'idfcfirstb': 'bank',
  'icicibank': 'bank',
  'sbin': 'bank',
  'axisbank': 'bank',
  'hdfcbank': 'bank',
  'kotakbank': 'bank',
  'indusindbk': 'bank',
  'tataconsum': 'fmcg',
  'vbl': 'fmcg',
  'radico': 'fmcg',
  'pghh': 'fmcg',
  'mcdowell-n': 'fmcg',
  'emamiltd': 'fmcg',
  'marico': 'fmcg',
  'colpal': 'fmcg',
  'ubl': 'fmcg',
  'itc': 'fmcg',
  'godrejcp': 'fmcg',
  'dabur': 'fmcg',
  'britannia': 'fmcg',
  'nestleind': 'fmcg',
  'hindunilvr': 'fmcg',
  'ltts': 'it',
  'tcs': 'it',
  'infy': 'it',
  'techm': 'it',
  'hcltech': 'it',
  'coforge': 'it',
  'lti': 'it',
  'wipro': 'it',
  'mphasis': 'it',
  'mindtree': 'it',
  'tvtoday': 'media',
  'tv18brdcst': 'media',
  'dbcorp': 'media',
  'pvr': 'media',
  'jagran': 'media',
  'suntv': 'media',
  'zeel': 'media',
  'network18': 'media',
  'inoxleisur': 'media',
  'dishtv': 'media',
  'welcorp': 'metal',
  'aplapollo': 'metal',
  'jindalstel': 'metal',
  'hindcopper': 'metal',
  'vedl': 'metal',
  'adanient': 'metal',
  'sail': 'metal',
  'coalindia': 'metal',
  'hindalco': 'metal',
  'nationalum': 'metal',
  'nmdc': 'metal',
  'hindzinc': 'metal',
  'tatasteel': 'metal',
  'ratnamani': 'metal',
  'jswsteel': 'metal',
  'divislab': 'pharma',
  'torntpharm': 'pharma',
  'cipla': 'pharma',
  'drreddy': 'pharma',
  'sunpharma': 'pharma',
  'lupin': 'pharma',
  'cadilahc': 'pharma',
  'alkem': 'pharma',
  'auropharma': 'pharma',
  'biocon': 'pharma',
  'aegischem': 'oilandgas',
  'ioc': 'oilandgas',
  'bpcl': 'oilandgas',
  'castrolind': 'oilandgas',
  'hindpetro': 'oilandgas',
  'reliance': 'oilandgas',
  'atgl': 'oilandgas',
  'mgl': 'oilandgas',
  'petronet': 'oilandgas',
  'igl': 'oilandgas',
  'gail': 'oilandgas',
  'oil': 'oilandgas',
  'gujgasltd': 'oilandgas',
  'ongc': 'oilandgas',
  'gspl': 'oilandgas',
  'm&m': 'auto',
  'tiindia': 'auto',
  'abbotindia': 'pharma',
  'alembicltd': 'pharma',
  'gland': 'pharma',
  'glenmark': 'pharma',
  'granules': 'pharma',
  'ipcalab': 'pharma',
  'lauruslabs': 'pharma',
  'natcopharm': 'pharma',
  'pfizer': 'pharma',
  'star': 'pharma'}
# Out:
# dict

# %%
stock = pd.DataFrame()

# %%
s = []
i = []
for key in w:
    val1 = key
    s.append(val1)
for value in w.values():
    val2 = value
    i.append(val2)
stock['Symbol'] = s
stock['Industry'] = i
stock
# Out:
#          Symbol Industry
# 0    bharatforg     auto
# 1      exideind     auto
# 2    balkrisind     auto
# 3      boschltd     auto
# 4           mrf     auto
# ..          ...      ...
# 107     ipcalab   pharma
# 108  lauruslabs   pharma
# 109  natcopharm   pharma
# 110      pfizer   pharma
# 111        star   pharma
#
# [112 rows x 2 columns]

# %%
auto = stock.query("Industry=='auto'")
auto
# Out:
#          Symbol Industry
# 0    bharatforg     auto
# 1      exideind     auto
# 2    balkrisind     auto
# 3      boschltd     auto
# 4           mrf     auto
# 5        maruti     auto
# 6      ashokley     auto
# 7      tvsmotor     auto
# 8    tatamotors     auto
# 9    bajaj-auto     auto
# 10    eichermot     auto
# 11   amarajabat     auto
# 12   heromotoco     auto
# 100         m&m     auto
# 101     tiindia     auto
