# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (9.0,9.0)
from IPython.display import Image

# %%
image = cv2.imread("abc.png",cv2.IMREAD_COLOR)

plt.imshow(image[:,:,::-1])

# %%
# Line
imageLine = image.copy()
cv2.line(imageLine,(200,100),(400,100),(0,255,255), thickness=5, lineType=cv2.LINE_AA);
plt.imshow(imageLine[:,:,::-1])

# %%
# Circle
imageCircle = image.copy()
cv2.circle(imageCircle,(900,500),100,(0,0,255),thickness=5,lineType=cv2.LINE_AA);
plt.imshow(imageCircle[:,:,::-1])

# %%
# Rectangle
imageRectangle = image.copy()
cv2.rectangle(imageRectangle,(500,100),(700,600),(255,0,255),thickness=5,lineType=cv2.LINE_8);
plt.imshow(imageRectangle[:,:,::-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15884/517732026.py in <module>
#       1 # Rectangle
#       2 imageRectangle = image.copy()
# ----> 3 cv2.rectangle(imageRectangle,(500,100),(700,600),(255,0,255),thickness=5,lineType=cv2.Line_8);
#       4 plt.imshow(imageRectangle[:,:,::-1])
#
# AttributeError: module 'cv2.cv2' has no attribute 'Line_8'
