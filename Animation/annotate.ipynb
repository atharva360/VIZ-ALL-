# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (9.0,9.0)
from IPython.display import Image

# %%
image = cv2.imread("abc.png",cv2.IMREAD_COLOR)

plt.imshow(image[:,:,::-1])

# %%
# Line
imageLine = image.copy()
cv2.line(imageLine,(1750,100),(1750,1000),(0,255,255), thickness=5, lineType=cv2.LINE_AA);
plt.imshow(imageLine[:,:,::-1])

# %%
# Circle
imageCircle = image.copy()
cv2.circle(imageCircle,(650,400),300,(0,0,255),thickness=5,lineType=cv2.LINE_AA);
plt.imshow(imageCircle[:,:,::-1])

# %%
# Rectangle
imageRectangle = image.copy()
cv2.rectangle(imageRectangle,(500,100),(700,600),(255,0,255),thickness=5,lineType=cv2.LINE_8);
plt.imshow(imageRectangle[:,:,::-1])
